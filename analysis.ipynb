# %%
import pandas as pd
df = pd.read_excel("/content/student_data.csv.xlsx")
df["Student"] = df["Student"].str.strip()
df.head()
# Out:
#     Student  Study_hours  Sleep_hours  Attendance  Marks
# 0     Arjun            2            6          70     45
# 1     Priya            5            7          85     72
# 2  Karthick            7            8          90     88
# 3     Divya            3            5          60     50
# 4     Rahul            6            7          80     75

# %% [markdown]
# The `df.head()` method is used to display the first 5 rows of a pandas DataFrame. You can specify a different number of rows by passing an integer argument, for example, `df.head(10)` would display the first 10 rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student      10 non-null     object
#  1   Study_hours  10 non-null     int64
#  2   Sleep_hours  10 non-null     int64
#  3   Attendance   10 non-null     int64
#  4   Marks        10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#        Study_hours  Sleep_hours  Attendance      Marks
# count    10.000000    10.000000   10.000000  10.000000
# mean      5.000000     6.500000   78.300000  68.200000
# std       2.581989     1.080123   14.929836  20.492817
# min       1.000000     5.000000   50.000000  35.000000
# 25%       3.250000     6.000000   71.250000  52.500000
# 50%       5.000000     6.500000   81.000000  71.000000
# 75%       6.750000     7.000000   88.750000  84.750000
# max       9.000000     8.000000   96.000000  95.000000

# %%
df.isnull().sum()
# Out:
# Student        0
# Study_hours    0
# Sleep_hours    0
# Attendance     0
# Marks          0
# dtype: int64

# %%
df["Marks"].mean()
# Out:
# np.float64(68.2)

# %%
df.loc[df["Marks"].idxmax()]
# Out:
# Student        Rohit
# Study_hours        9
# Sleep_hours        7
# Attendance        96
# Marks             95
# Name: 8, dtype: object

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Study_hours"], df["Marks"])
plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.savefig("study_analysis.png")
plt.show()

# %%
plt.figure(figsize=(8,5))
df.plot(x="Student", y="Marks", kind="bar", ax=plt.gca())
plt.title("Marks by Student")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.tight_layout()
plt.savefig("student_marks_bar_chart.png")
plt.show()
